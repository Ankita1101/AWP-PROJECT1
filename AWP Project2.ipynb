# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
Covid_data = covid_data.groupby('State/UnionTerritory').Confirmed.sum()
total_data = covid_data.replace("Bihar***","Bihar")

# %%
covid_data = pd.read_csv("covid_19_india.csv")

# %%
covid_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  30-01-2020  6:00 PM               Kerala
# 1          2  31-01-2020  6:00 PM               Kerala
# 2          3  01-02-2020  6:00 PM               Kerala
# 3          4  02-02-2020  6:00 PM               Kerala
# 4          5  03-02-2020  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  07-07-2021  8:00 AM            Telangana
# 16846  16847  07-07-2021  8:00 AM              Tripura
# 16847  16848  07-07-2021  8:00 AM          Uttarakhand
# 16848  16849  07-07-2021  8:00 AM        Uttar Pradesh
# 16849  16850  07-07-2021  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
plt.figure(figsize=(12,8))
sns.pairplot(covid_data)

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=covid_data,x="State/UnionTerritory")
plt.xticks(rotation=70)
plt.tight_layout()
plt.show()

# %%
sns.set_style(style='whitegrid')

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Date',y='Confirmed',data=covid_data)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set_style(style='whitegrid')
sns.lineplot(x='Date',y='Deaths',data=covid_data)

plt.xticks(rotation=70)
plt.tight_layout()

# %%
sns.set_style(style='whitegrid')
plt.figure(figsize=(15,8))
sns.relplot(x='Date',y='Cured',data=covid_data)

plt.xticks(rotation=60)
plt.tight_layout()

# %%
plt.figure(figsize=(25,10))
sns.lineplot(x='State/UnionTerritory',y='Confirmed',data=covid_data)

plt.xticks(rotation=70)
plt.tight_layout()
